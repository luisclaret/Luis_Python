# %% [markdown]
# # Dato tipo int y float con operaciones

# %%
4 + 4, 4 - 1, 4 * 2, 4 / 2, 5 // 2, 5 ** 2
# Out:
# (8, 3, 8, 2.0, 2)

# %%
12.1, type(12.1)
# Out:
# (12.1, float)

# %%
12, type(12)
# Out:
# (12, int)

# %% [markdown]
# # Dato tipo string

# %%
"hola", type("hola")
# Out:
# ('hola', str)

# %%
"hola" + " mundo"
# Out:
# 'hola mundo'

# %%
"hola" * 3
# Out:
# 'holaholahola'

# %% [markdown]
# # No tan importantes

# %%
0xFF, 0b1010, 0o12
# Out:
# (255, 10, 10)

# %%
2 >> 1, 1 >> 2
# Out:
# (1, 0)

# %% [markdown]
# # Booleanos

# %%
True, False
# Out:
# (True, False)

# %% [markdown]
# ## AND, OR y NOT

# %%
True and True, True and False, False and True, False and False
# Out:
# (True, False, False, False)

# %%
True or True, True or False, False or True, False or False
# Out:
# (True, True, True, False)

# %%
not True, not False
# Out:
# (False, True)

# %% [markdown]
# # Extras

# %% [markdown]
# # Variables en Python (asignan y usan)

# %%
var1 = 10
type(var1)
# Out:
# int

# %%
snake_case = "Luis" # Uso para nombres de variables y funciones
PascalCase = "Yesica" # Uso para nombre de las clases
camelCase = "Luis" # No se usa en Python
otracosa = "Otra cosa" # casi no se usa, no genera organizacion

# %% [markdown]
# # EJERCICIO

# %%
# First basic calculator program
num1 = 12
num2 = 4
suma = num1 + num2
resta = num1 - num2
multiplicacion = num1 * num2
division = num1 / num2
print("The results are: ")
print("suma: ", suma, "resta: ", resta, "multiplicacion: ", multiplicacion, "division: ", division)
# Out:
# The results are:
# suma:  16 resta:  8 multiplicacion:  48 division:  3.0
