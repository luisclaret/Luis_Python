# %%
print("hola mundo")
# Out:
# hola mundo

# %%
numero = input("Hey introduce un numero")

# %%
print(type(numero))
print(numero)
# Out:
# <class 'str'>
# 20

# %%
numero = float(numero)
numero
# Out:
# 20.0

# %%
numero = int(numero)
numero
# Out:
# 20
